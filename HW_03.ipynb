# %% [markdown]
# # Дане домашнє завдання буде повністю пов'язане з лінійною регресією та її реалізацією. Отож розіб'ємо наше домашнє завдання на декілька частин:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # напишіть функцію гіпотези лінійної регресії у векторному вигляді:

# %%
def h(w_0, w_1, x):
    return w_0 + w_1 * x

# %% [markdown]
# # створіть функцію для обчислення функції втрат у векторному вигляді:

# %%
def loss_func(w_0, w_1, input_data, output_data):
   
    sum = 0
    
    for x, y in zip(input_data, output_data):
        sum += (h(w_0, w_1, x) - y) ** 2

    return sum / (2 * len(input_data))

# %% [markdown]
# # реалізуйте один крок градієнтного спуску:

# %%
def gradient_step(X, y, w, step):
  N = len(y) # Визначаємо кількість варіантів
  
  error = h(w_0, w_1, b) - y
  grad = (1/N) * np.dot(X.T, error)
  return w - step * grad

# %%
df = pd.read_csv('Housing.csv')
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.plot(x = 'area', y = 'price', kind = "scatter", figsize=(15,8))
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
sns.set_style('darkgrid')

sns.pairplot(
    df,
    vars = ['price',	'area',	'bedrooms',	'bathrooms',	'stories'],
    hue = 'basement'
)
plt.show()

# %%
df_corr = df[['area', 'price']].corr()
df_corr
# Out:
#            area     price
# area   1.000000  0.535997
# price  0.535997  1.000000
